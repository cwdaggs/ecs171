# %% [markdown]
# Activity 2:
# What is this gate? Identify the logical gate for every neuron. Show all the steps taken to solve this. Assume the threshold for the activation function is 0.

# %% [markdown]
# ![2021-10-17%2021-36.jpg](attachment:2021-10-17%2021-36.jpg)
